# %%
import pandas as pd
df=pd.read_csv("../data/latest_news.csv")
print(df.columns)
print(df.head(2))
# Out:
# Index(['title', 'description', 'content', 'source', 'publishedAt', 'url'], dtype='object')
#                                                title  \
# 0  Monero prices rocket to $438 amid $120 million...
# 1  Tether Crypto Executive Leaves as Real Estate ...
#
#                                          description  \
# 0  Onchain sleuth ZachXBT traced remaining funds ...
# 1  Tether crypto executive has stepped down after...
#
#                                              content                 source  \
# 0  The rest was scattered. ZachXBT traced more th...               CoinDesk
# 1  Tether crypto executive has stepped down after...  Bitcoinfoundation.org
#
#             publishedAt                                                url
# 0  2026-06-12T11:10:51Z  https://www.coindesk.com/markets/2026/06/12/mo...
# 1  2026-06-12T10:53:32Z  https://bitcoinfoundation.org/news/stablecoin-...

# %%
print(df.isna().sum())
# Out:
# title          0
# description    1
# content        0
# source         0
# publishedAt    0
# url            0
# dtype: int64
